# %%
C
# Out:
# Class distribution:
# DEATH_EVENT
# 0    203
# 1     96
# Name: count, dtype: int64
# Class weights: {0: 0.7364532019704434, 1: 1.5572916666666667}
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.6334 - loss: 0.7067 - val_accuracy: 0.6500 - val_loss: 0.6639
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7606 - loss: 0.6421 - val_accuracy: 0.6833 - val_loss: 0.6314
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7814 - loss: 0.5503 - val_accuracy: 0.7333 - val_loss: 0.5887
# Epoch 4/100
# ...

# %%
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=1)
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Test Loss: {test_loss:.4f}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8042 - loss: 0.4633
# Test Accuracy: 0.8000
# Test Loss: 0.4668

# %%
import numpy as np
from tensorflow.keras.models import load_model

# Load the trained model
model = load_model('heart_failure.h5')

# Example input for testing (replace with actual data)
test_input = np.array([[75, 1, 582, 0, 20, 1, 127000, 1.9, 130, 1, 0, 4]])

# Normalize the input using the same scaler
test_input_normalized = scaler.transform(test_input)

# Make predictions
prediction = model.predict(test_input_normalized)
risk = prediction[0][0]

# Interpret the result
if risk > 0.5:
    print(f"High risk of heart failure: {risk:.2f}")
else:
    print(f"Low risk of heart failure: {risk:.2f}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ...

# %%
# Save the scaler to a file
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
